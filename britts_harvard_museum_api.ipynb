# %% [markdown]
# # `britts_in_harvard`
#
# A program to fetch the names and birth places of all British persons listed in the Harvard Museum API

# %%
# start with importing requests
import requests

# %% [markdown]
# Get an API first

# %%
'''
need to generate an API by submitting 
a request at: https://docs.google.com/forms/d/e/1FAIpQLSfkmEBqH76HLMMiCC-GPPnhcvHC9aJS86E32dOd0Z8MpY2rvQ/viewform 
'''

api = 'fc2c1ee0-871e-11ea-901a-298e9b8e7864'

# %% [markdown]
# Objective:Get names and birthplaces of ALL Britts from Harvard API.
#
# Endpoint to use: Person
#
# Query parameters available at: https://github.com/harvardartmuseums/api-docs/blob/master/sections/person.md
#
# An example tells us that culture can be used to query persons of a certain Nationality

# %%
# base URL then becomes
url = 'https://api.harvardartmuseums.org/person?q=culture:British'

# %% [markdown]
# ##  `process_data`
#
# Helper function to extract attributes of interest from records of personal data in Harvard Museum (HM) records

# %%
'''
  List of dictionaries -> List of dictionaries
  purpose: takes a list of person attributes and extract 3 attributes of interest for each person

  args(raw_incidents): records of persons with culture = British 
'''
def process_data(raw_incidents):
  #iterate the results and only grab the properties that we are interested in
  return [{
      'name': raw_incidents[incident]['displayname'],  #[<incident is the index of record>][<target attribute>]
      'birthplace': raw_incidents[incident]['birthplace'],
      'nationality': raw_incidents[incident]['culture']
  } for incident in range(len(raw_incidents))]

# %% [markdown]
# # 'britts_in_hm_data'
#
# Function to extract Britain nationals from Harvard Museum (hm) 'person' records that span multiple pages

# %%
def britts_in_hm_data(): # hm= Harvard Museum
  import requests
  # declare a list to store all results
  incidents = []
  # declare variables to track pages amount since data spread across multiple pages
  page = 1
  # make an initial call
  url = 'https://api.harvardartmuseums.org/person?q=culture:British'
  # define api
  api = 'fc2c1ee0-871e-11ea-901a-298e9b8e7864'
  # get maximum records per call i.e. 100 and set page to a constant 
  query = {"apikey": api, "size": 100, "page": page}  
  
  response = requests.get(url, query)
  
  # make sure we got a valid response
  if(response.ok):
    # get the full data from the response
    data = response.json()
    
    # get the meta data
    meta_data = data['info']

    total = meta_data['totalrecords']
    # print('There is a total of {} results to fetch'.format(total))

    # data spread over multiple pages
    total_pages = meta_data['pages']
    # print('And a total of {} pages to process'.format(total_pages))
    
    # process the results we have so far
    incidents = process_data(data['records'])
    
    # increment page number to skip those already accessed
    page = page + 1
    
    # loop over all pages. Alternatively could write a for loop since total_pages is pre-determined
    while page <= total_pages:
      query = {"apikey": api, "size": 100, "page": page} 
      response = requests.get(url, query)
      if(response.ok):
        #  now incidents will be the old values plus the new ones      
        incidents = incidents + process_data(response.json()['records'])
        # increment page number
        page = page + 1
    # print("This yields the following list:")
    return incidents

# %%
# the function
britts_in_hm_data()
# Out:
# [{'birthplace': None, 'name': 'Alastair Wright', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'David Charles Read', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Herbert Barraud', 'nationality': 'British'},
#  {'birthplace': 'Leicester, England',
#   'name': 'John Fulleylove',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Barraud & Jerrard', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Joachim Smith', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John I. Frost', 'nationality': 'British'},
#  {'birthplace': 'Berlin', 'name': 'Frank Auerbach', 'nationality': 'British'},
#  {'birthplace': 'London',
#   'name': 'Hablot Knight Browne ("Phiz")',
#   'nationality': 'British'},
#  {'birthplace': 'Melbourne, Australia',
#   'name': 'Horace Brodzky',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'James Clarke Hook', 'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'Constance Mary Pott',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'William C. Ward', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Heneage Finch, Fourth Earl of Aylsford',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Fred Bruckmann', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Herbert John Finn', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Lodge', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Feake', 'nationality': 'British'},
#  {'birthplace': 'Berlin', 'name': 'Lucian Freud', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'J.J. Hobbiss', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Hennah & Kent', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Gilpin', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William E. Frost', 'nationality': 'British'},
#  {'birthplace': 'Germany',
#   'name': 'Hayman Selig Mendelssohn',
#   'nationality': 'British'},
#  {'birthplace': 'Canterbury, Kent, England',
#   'name': 'Tacita Dean',
#   'nationality': 'British'},
#  {'birthplace': 'London', 'name': 'Ewan Gibbs', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Thomas Folkingham', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Messrs. Lucas', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Henry Maull & Co.', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'H. Lenthall', 'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'Henry Webber',
#   'nationality': 'British'},
#  {'birthplace': 'London',
#   'name': 'Lynn Russell Chadwick',
#   'nationality': 'British'},
#  {'birthplace': 'North Wales, Great Britain',
#   'name': 'Andrzej Jackowski',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Bill Woodrow', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Dorrell and Son', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Henry Alexander Ogg', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Philip Reinagle', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'P. Devine', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Mr. Hammond', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Johnson', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Nicholas Wollaston', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Pingo', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Wheeler & Day', 'nationality': 'British'},
#  {'birthplace': 'Norwich, England',
#   'name': 'Bernard William Meadows',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Burgwitz & Co.', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Thomas Bamford', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Burns & Lambert', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'S.E. Poulton', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Kingsbury & Notcutt', 'nationality': 'British'},
#  {'birthplace': 'Cork', 'name': 'Daniel Maclise', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Wilfred de Glehn', 'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'William Holman Hunt',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Symonds & Co.', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Sydney E. Letts', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'George Henry Harlow', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'A. W. Wills', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'W. Leuchars', 'nationality': 'British'},
#  {'birthplace': 'Wortley, England',
#   'name': 'Philipp William May',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Lloyd & Jefferson', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'J. Griffin & Co.', 'nationality': 'British?'},
#  {'birthplace': None, 'name': 'A. & G. Taylor', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Allen Jones', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Nash', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Hood', 'nationality': 'British?'},
#  {'birthplace': 'Edinburgh, Scotland',
#   'name': 'Alexander Nasmyth',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'W. & A. H. Fry', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'George Milner Gibson Jerrard',
#   'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Alfred Ellis & Walery',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Gunn & Stuart', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Booth Grey', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'James Baker Pyne', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John M. Swan', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Henry John Whitlock', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'George Richmond', 'nationality': 'British'},
#  {'birthplace': 'Plymouth, England',
#   'name': 'John Skinner Prout',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Edwards & Jones', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'J. D. Steele', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Lewis Vulliamy', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Rand', 'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'Howard Hodgkin',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'W. Green', 'nationality': 'British?'},
#  {'birthplace': 'England',
#   'name': 'Joseph Blackburn',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Isaac Ribouleau', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Samuel Margas', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Gerald Laing and Peter Phillips',
#   'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'Peter Joseph',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Thomas Leigh', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'B. Greene', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Maddox', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Thomas Monro', 'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'George Howard, Ninth Earl of Carlisle',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Lukin', 'nationality': 'British'},
#  {'birthplace': 'Plympton, England',
#   'name': 'Sir Joshua Reynolds',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Richard Penny', 'nationality': 'British'},
#  {'birthplace': 'Bradford, Yorkshire, England',
#   'name': 'William Rothenstein',
#   'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Hugh William Williams',
#   'nationality': 'British'},
#  {'birthplace': 'Dublin, Ireland',
#   'name': 'Stanhope Alexander Forbes',
#   'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'John Frederick Lewis',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Vincent', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Kenneth Martin', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'J. (?) Paulet', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'James Morison', 'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'William Blake',
#   'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'William Tassie',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'James Heath', 'nationality': 'British'},
#  {'birthplace': 'Metz', 'name': 'David Willaume I', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Havell', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'M. S. Barenger', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Henry Haig', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Robert Charles Bell', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Finden', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Edward Paxman Brandard',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Thomas Hodgetts', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'N. Burnwhite', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Byrne', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Andrew Birrell', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Thomas Holloway', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'I. S. Bailey', 'nationality': 'British?'},
#  {'birthplace': None, 'name': 'John Carter II', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'William Bernard Cooke',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'S. C. Jones', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Holl', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Samuel Ireland', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Hercules B. Brabazon',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'G. Granville', 'nationality': 'British'},
#  {'birthplace': 'South Wales',
#   'name': 'William A. Davies',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'S. Fisher', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Edward Dalziel', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'John Alexander Gresse',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Edward McInnes', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Peter Moran', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Joseph Nash', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Payne', 'nationality': 'British'},
#  {'birthplace': 'Liverpool',
#   'name': 'George Stubbs',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Humphrey Payne', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Fuller White', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Edward Levy Montefiore',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'W. Wright', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'James Roberts', 'nationality': 'British'},
#  {'birthplace': 'Bristol, England',
#   'name': 'Stanley Anderson',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Jones', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'J. Henshall', 'nationality': 'British'},
#  {'birthplace': 'Killbride',
#   'name': 'William Baillie',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Benjamin Smith', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Knibb', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Daniel Lerpinière', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Strang', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Josiah Wood Whymper', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Elizabeth Byrne', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Renold Elstrack', 'nationality': 'British'},
#  {'birthplace': 'London', 'name': 'James Fittler', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'William Turner Davey',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Thales Fielding', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'H. Bibby', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Arthur Evershed', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Edward Edwards', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Anthony Fogg', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Edward Goodall', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'George Thomas Doo', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Thomas Chambars', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Matthew Liart', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'David Loggan', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Frederick Bacon', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Joseph Goupy', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'James Watson', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'George Dance', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'James Peake', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'James Smith', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'James Thomson', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Jean Reavey', 'nationality': 'British'},
#  {'birthplace': 'Auckland, New Zealand',
#   'name': 'Oswald Birley',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Greig', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'George Henry Phillips',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Lumb Stocks', 'nationality': 'British'},
#  {'birthplace': 'Grangemouth, Scotland',
#   'name': 'Alan Davie',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Thomas Woolnoth', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'D. Allen', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Samuel Whalley', 'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'Frederick Hollyer',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Thomas Major', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Richard James Lane', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Pether', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Clark', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'George Chinnery', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Wright', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Wykeham Archer', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Coney', 'nationality': 'British'},
#  {'birthplace': 'Norwich, England',
#   'name': 'John Sell Cotman',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Michael Ayrton', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Edward Henry Corbould',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'James Jefferys', 'nationality': 'British'},
#  {'birthplace': None, 'name': '? Warner', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Edward Scriven', 'nationality': 'British'},
#  {'birthplace': 'Tiverton, England',
#   'name': 'Richard Cosway',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'F. York', 'nationality': 'British?'},
#  {'birthplace': None, 'name': 'J. C. Easling', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Chartier', 'nationality': 'British'},
#  {'birthplace': 'London',
#   'name': 'Charles Grignion the Elder',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Philip Dawe', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Thomas Watson', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Thomas Scott', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Harry DeMaine', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Charles Wilkin', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'W. Joseph Edwards', 'nationality': 'British'},
#  {'birthplace': 'Norwich England',
#   'name': 'John Crome',
#   'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'Richard Hamilton',
#   'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'William Young Ottley',
#   'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Mr. & Mrs. S. G. Payne',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Anne Allen', 'nationality': 'British'},
#  {'birthplace': 'Orton Longueville, Huntingdonshire, England',
#   'name': 'Samuel Buckle',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Gordon House', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Rotary Photographic Company',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Russell', 'nationality': 'British?'},
#  {'birthplace': None,
#   'name': 'Lionel Alfred Crichton',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Greenaway', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Peter Bergheim', 'nationality': 'British?'},
#  {'birthplace': None, 'name': 'Lassalle Ltd.', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Francis Wheatley', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Bellers', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Mary Beale', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Iorwerth Grey Lloyd', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Thomas Beech', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Jane Benham Hay', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Esther Acklom', 'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'William Frederick Witherington',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Milton', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'H. Jeayes', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Robert Smirke', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'R Slann', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Bispham Dickinson', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'David Parkes', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Roberts', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Amelia Noel', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Collins', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Francis Barlow', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Felix Martin Miller', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Robert Nixon', 'nationality': 'British'},
#  {'birthplace': 'Davenport, Devon, United Kingdom',
#   'name': 'Linnaeus Tripe',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Susan Vivares', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Robert Muller', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'George Carter', 'nationality': 'British'},
#  {'birthplace': 'Sheffield, England',
#   'name': 'Alan Charlton',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'James Ramsay', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Samuel William Fores',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Thomas Smith', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Peter Stephens', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Edward Francis Burney',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'James Moore', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Samuel S. Smith', 'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'Chloe Dewe Mathews',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Bouch', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'J. Wright', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Henry Bryer', 'nationality': 'British'},
#  {'birthplace': 'Wallasey, England',
#   'name': 'Maxwell Fry',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Asplet & Green', 'nationality': 'British?'},
#  {'birthplace': None, 'name': 'Bentley', 'nationality': 'British?'},
#  {'birthplace': 'St. Louis, MO',
#   'name': 'Thomas Stearns Eliot',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Henry Edridge', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'James Wilfred Freeth',
#   'nationality': 'British'},
#  {'birthplace': 'Conwy, Wales',
#   'name': 'John Gibson',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Glover', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'C. Ferranti', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'H. N. King', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Richard Gurney and Thomas Cooke II',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Lombardi & Co.', 'nationality': 'British'},
#  {'birthplace': 'Bangor, Wales',
#   'name': 'Richard Deacon',
#   'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'Susan Derges',
#   'nationality': 'British'},
#  {'birthplace': 'Reading, England',
#   'name': 'William Giles',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Daniel Gardner', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Fisher, Son, & Jackson',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Samuel A. Walker', 'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'Bill Jacklin',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'E. Smorthwaite', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Peter Bateman', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Joseph Lock', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'J. Davis Burton', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'George Bankart', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'H. Pyall', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Francis Pages', 'nationality': 'British'},
#  {'birthplace': 'Edinburgh, Scotland',
#   'name': 'David Roberts',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Henry Morris', 'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'Bridget Riley',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Robert Austin', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Howison', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Humphrys', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Louis Haghe', 'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'Augustus Wall Callcott',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'George Barnard', 'nationality': 'British'},
#  {'birthplace': 'Dorrington, England',
#   'name': 'John Boydell',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Samuel Davenport', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Henry Cousins', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Edmund Dorrell', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Sarah Green', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William P. Robins', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Ogborne', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'James Stewart', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Isaac S. Wright', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Simon Watts', 'nationality': 'British'},
#  {'birthplace': 'Middlesex, England',
#   'name': 'Isaac Robert Cruikshank',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Wothlytype', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Adams & Stilliard', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'F. Mallhay', 'nationality': 'British?'},
#  {'birthplace': None, 'name': 'Christian Herald', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': "St. James's Photographic Gallery",
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'George Mills', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Walter G. Lewis', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Richard Burbage', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'John Hamilton Mortimer',
#   'nationality': 'British'},
#  {'birthplace': 'Tynemouth, England',
#   'name': 'Myles Birket Foster',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'R M Hodgetts', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Thomas Brabazon Aylmer',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Noel Rooke', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Robert Jennings', 'nationality': 'British'},
#  {'birthplace': 'London',
#   'name': 'Christopher R. W. Nevinson',
#   'nationality': 'British'},
#  {'birthplace': 'Edinburgh',
#   'name': 'William Bell Scott',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'George Chambers', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Robert Batty', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Humphry Repton', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'G. F. Storm', 'nationality': 'British'},
#  {'birthplace': 'Penegoes, Wales',
#   'name': 'Richard Wilson',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Henry Brind', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Margaret Curtis Haythorne',
#   'nationality': 'British'},
#  {'birthplace': 'Macclesfield, England',
#   'name': 'David Shrigley',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Henry Hudson', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'H. C. Balding', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'George Barnard', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William John Alais', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'James H. Kernot', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'J. L. Cranstone', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Henry Chawner & John Emes',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Anker Smith', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Keyse Sherwin', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Robert William Sievier',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'J. Quartley', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Claude Flight', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Paradise', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Kinnard', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John White', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Joseph Pastorini', 'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'John Webber',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Thomas Jones', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'J. Kennerly', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'John Michael Williams',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'George Robertson', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Edward Duncan', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Elizabeth Ellis', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'C. John Mayle Whichelo',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Ackermann & Co.', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Shaw', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Hackwood', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Robert Laurie', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'George Wilmot Bonner',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Hardman & Co.', 'nationality': 'British'},
#  {'birthplace': 'Ruabon, Wrexham, Wales',
#   'name': 'John Downman',
#   'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'Nicola Tyson',
#   'nationality': 'British'},
#  {'birthplace': None,
#   'name': "Maker's mark IS with cinquefoil below",
#   'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'Richard Selesnick',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Ellicott', 'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'Thomas Girtin',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Byrne & Co.', 'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'Thomas Charles Farrer',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Smithson', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Ernest Edwards', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Harvey, Reynolds & Co.',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Thomas Lewis', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'J. Hinton', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Thomas Frye', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Lambert Weston & Son',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'W. H. Midwinter', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Francis Garthorne', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Joseph Stannard', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Maw & Company', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Cundall, Downes & Co.',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Joseph Davis', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'T. Coleman', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Sarony, Hill & Thrupp',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Hoskins & Grant', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Lacy Theatrical Bookseller',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Josh Clements', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'D. Lama', 'nationality': 'British'},
#  {'birthplace': 'Sunderland, England',
#   'name': 'William Clarkson Stanfield',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Henry Hering', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Robert Abercrombie', 'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'Walter Greaves',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Douglas', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Hills & Saunders', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Maull & Fox', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Thomas Mann Baynes', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Thomas Humphrey Paget',
#   'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Charles Ernest Baudoux',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Dalton & Lucy', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Lock & Whitfield', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Keeling', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Turner & Drinkwater', 'nationality': 'British'},
#  {'birthplace': 'London',
#   'name': 'James Drumgole Linton',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Henry Burch, Jr.', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'J. M. D. Worsnop', 'nationality': 'British'},
#  {'birthplace': 'Oxford, England',
#   'name': 'Joseph Swain',
#   'nationality': 'British'},
#  {'birthplace': 'Haverfordwest, Wales',
#   'name': 'Gwen John',
#   'nationality': 'British'},
#  {'birthplace': 'Oxford, England',
#   'name': 'Henry William Taunt',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Lewis', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Albert Deneulain', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Peter Phillips', 'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'Marcus C. Stone',
#   'nationality': 'British'},
#  {'birthplace': 'Kirkcaldy, Scotland',
#   'name': 'Robert Adam',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Wilson & Beadell', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Arthur Severn', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Robin Tanner', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Dominic Serres', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Theodore Matthias von Holst',
#   'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Arthur Longley Vernon',
#   'nationality': 'British'},
#  {'birthplace': 'Ipswich',
#   'name': 'Henry George Todd',
#   'nationality': 'British'},
#  {'birthplace': 'Wiltshire, England',
#   'name': 'Ambrose McEvoy',
#   'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'Arthur Mackmurdo',
#   'nationality': 'British'},
#  {'birthplace': 'Bruges', 'name': 'Frank Brangwyn', 'nationality': 'British'},
#  {'birthplace': 'Burton-on-Trent, England',
#   'name': 'Arthur Mayger Hind',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Done & Co.', 'nationality': 'British'},
#  {'birthplace': 'London', 'name': 'Simeon Solomon', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Maclure, Macdonald & Co.',
#   'nationality': 'British'},
#  {'birthplace': 'Arnold, England',
#   'name': 'Richard Parkes Bonington',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Daniel Piers', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Hugh Lofting', 'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'John Ruskin',
#   'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'Graham Sutherland',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Andrew Raven', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Jonathan Richardson Sr.',
#   'nationality': 'British'},
#  {'birthplace': 'Cults, Fife',
#   'name': 'David Wilkie',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Stephen Buckley', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Seymour', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Thomas Northcote', 'nationality': 'British'},
#  {'birthplace': 'Hales -Owen, England',
#   'name': 'John Green',
#   'nationality': 'British?'},
#  {'birthplace': 'Dublin, Ireland',
#   'name': 'William Orpen',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Ruslen', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Anthony Nelme', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'George Pyne', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Joseph Clayton Bentley',
#   'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'Dante Gabriel Rossetti',
#   'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'Robert White',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Samuel Wood', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Horace Harral', 'nationality': 'British'},
#  {'birthplace': 'Reading, England',
#   'name': 'Robert Havell Jr.',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'H. Anelay', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'J. Angus', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Henry Gillard Glindoni',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Horsburgh', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'David Jones', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Francis Haward', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Bromley', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Nelson Dawson', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'George Keating', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Edmund Girling', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Saddler', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Dixon', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'William Faithorne the Elder',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Francis Singleton', 'nationality': 'British'},
#  {'birthplace': 'Truro, England',
#   'name': 'John Opie',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Alfred J. Downey', 'nationality': 'British'},
#  {'birthplace': 'Aberdeen, Scotland',
#   'name': 'Cosmo Alexander',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Charles Sherwin', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Thomas Gosden', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Henry Vizetelly', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Peter Mazell', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Thomas Brydon', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'A. M. Huffam', 'nationality': 'British'},
#  {'birthplace': 'Newcastle upon Tyne, England',
#   'name': 'Gerard Laing',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Skelton', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Greatbach', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Morris', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Edward Rooker', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Cecil C. Brewer', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Edward Wigan', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Orrin Smith', 'nationality': 'British'},
#  {'birthplace': None, 'name': '? Smyth', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'F. Pickering', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Henry Thomas Alken', 'nationality': 'British'},
#  {'birthplace': 'Glasgow, Scotland',
#   'name': 'Muirhead Bone',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'G. Barrett', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Gabriel Smith', 'nationality': 'British'},
#  {'birthplace': 'Budapest, Hungary',
#   'name': 'Agathe Sorel',
#   'nationality': 'British'},
#  {'birthplace': 'Newton Abbott, Devon England',
#   'name': 'John Angel',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Thomas Medland', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Arthur Pond', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Henry Meyer', 'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'Francis Cotes',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Cyril Power', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Walker', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Hall', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'James Tibbits Willmore',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'James Posselwhite', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Antoine Cardon', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Henry Edward Dawe', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Daniell', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Cochran', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'James Basire the Elder',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Francis Chesham', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Daniel Cary', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Bernard Cohen', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Lee-Hankey', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Forrest', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Thomas Gaugain', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'James Caldwall', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Andrew Duncan', 'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'Edward Dayes',
#   'nationality': 'British'},
#  {'birthplace': 'Nottingham, England',
#   'name': 'Samuel Bourne',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Wood', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'William Henry Worthington',
#   'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Eric William Ravilious',
#   'nationality': 'British'},
#  {'birthplace': 'Maidstone, England',
#   'name': 'William Woollett',
#   'nationality': 'British'},
#  {'birthplace': 'Wolverhampton, West Midlands, Britian',
#   'name': 'David Ward',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': '? Rivers', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Raphael Lamar West', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Sir John Charles Robinson',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Denziloe', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'G. B. Shaw', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Skippe', 'nationality': 'British'},
#  {'birthplace': 'Edinbugh, Scotland',
#   'name': 'William Home Lizars',
#   'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'John Baptist Jackson',
#   'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Charles William Cain',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'S. Paul', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'George J. Stodart', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'George Pike Nicholls',
#   'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Frederick Christian Lewis',
#   'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Benjamin Thomas Pouncy',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'C. Westwood', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Robert Williams', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Charles John Watson', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Norman Wilkinson', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Arthur Willmore', 'nationality': 'British'},
#  {'birthplace': 'Heywood, Lancashire, England',
#   'name': 'Roger Fenton',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Sebastian Crespell', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Thomas Sherratt', 'nationality': 'British'},
#  {'birthplace': 'Bois-le-Duc',
#   'name': 'Paul De Lamerie',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Christopher Wood', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Ebenezer Coker', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'William Russell Sedgfield',
#   'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Studio of Elliott & Fry',
#   'nationality': 'British'},
#  {'birthplace': 'Birmingham, England',
#   'name': 'Raymond Mason',
#   'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Samuel William Reynolds',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Adrian Nutbeem', 'nationality': 'British'},
#  {'birthplace': 'Kingston-on-Thames, England',
#   'name': 'Eadweard Muybridge',
#   'nationality': 'British'},
#  {'birthplace': 'Wexford Ireland',
#   'name': 'Francis Danby',
#   'nationality': 'British'},
#  {'birthplace': 'Sheffield, England',
#   'name': 'Derrick Greaves',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Robertson and Beato', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'F. Ralph', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Ann Winchester', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Izaak Walton', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Gill', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Westall', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Edmund Scott', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Evans', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'George Cattermole', 'nationality': 'British'},
#  {'birthplace': 'Morpeth, England',
#   'name': 'Luke Clennell',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Nicholas Hilliard', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Hodges Benwell', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Charles Bridges', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Montresor', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Samuel Cooper', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Brand', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Patrick Cunningham', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Richard Ansdell', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Nixon', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Harrison William Weir',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Claude Nattes', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Orme', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Thomas Streatfield', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'George Smith', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Alfred Clint', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Thomas McLean', 'nationality': 'British'},
#  {'birthplace': 'Wimbeldon', 'name': 'Thomas Tegg', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Richard Westmacott II',
#   'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'William Armfield Hobday',
#   'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Charles Lock Eastlake',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Robert Havell I', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'J. Turner', 'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'Adam McEwen',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Sir John Gilbert', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Parrott', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Guy Head', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'William Henry Freeman',
#   'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Theodore Henry Adolphus Fielding',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Robert Home', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Abraham Pether', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Henry Singleton', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Humphrey', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Nicholas Serota', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Robert Blakey PhD.', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'James Bourne', 'nationality': 'British'},
#  {'birthplace': 'Bury St Edmunds, Suffolk',
#   'name': 'George Wickes',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Thomas Black', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Oram', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Rodwell & Martin', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Gillows of Lancaster',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'The Arundel Society', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Stereoscopic Company Limited',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Hamilton', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Joseph Angell Sr.', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Henry Peach Robinson',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Thomas Child', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Henry Bradbury', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Frank Briggs', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Moira & Haigh', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Gamble', 'nationality': 'British'},
# ...
#  {'birthplace': None, 'name': 'John Byrne', 'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'Thomas Shotter Boys',
#   'nationality': 'British'},
#  {'birthplace': 'Guildford, Surrey, England',
#   'name': 'Samuel Laurence',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'M. Dubourg', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Richard Westall', 'nationality': 'British'},
#  {'birthplace': 'Geneva, Switzerland',
#   'name': 'Charles Ricketts',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Russell', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Browne', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'James Davis Cooper', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Charles Knight', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Jacob George Strutt', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Edward Louis Laurenson',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Christopher Norton', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Matthew Cooper I', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Sharp', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Ward I', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'R. Petley', 'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'Joseph Wilton',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'James C. Allen', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Thomas Higham', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Mason Jackson', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Helen Tory', 'nationality': 'British'},
#  {'birthplace': 'Dronryp, Netherlands',
#   'name': 'Lawrence Alma-Tadema',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Axel Herman Haig', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'William James Linton',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'W. H. Watt', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Henry Robinson', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Walcot', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John ? Miller', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'B. J. Renton', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Nutter', 'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'John Tenniel',
#   'nationality': 'British'},
#  {'birthplace': 'Boston, Mass., USA',
#   'name': 'Alvin Langdon Coburn',
#   'nationality': 'British'},
#  {'birthplace': 'Luton, UK', 'name': 'Alan Uglow', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'C. Warren', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Philip Gilbert Hamerton',
#   'nationality': 'British'},
#  {'birthplace': 'Sheffield, Yorkshire on October 12.',
#   'name': 'John Hoyland',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Elliot', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Alexander Bannerman', 'nationality': 'British'},
#  {'birthplace': 'Durham',
#   'name': 'Newton Smith Limbird Fielding',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Francis Legat', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Henry George Rushbury',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Alexander Cozens', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Walter Geikie', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'H. Griffiths', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Joseph Saunders', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Joseph Farington', 'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'George Cruikshank',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Henry Quilley', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Samuel Smith', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Sidney Tushingham', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'J. Stephenson', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'H. O. Smith', 'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'Roland Algernon Penrose',
#   'nationality': 'British'},
#  {'birthplace': 'Glasgow, Scotland',
#   'name': 'James Stirling',
#   'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Arthur Radclyffe Dugmore',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'T.B.G.S. Dalziel', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Matthew William Peters',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Richard Houston', 'nationality': 'British'},
#  {'birthplace': 'Chesterfield, Derbyshire, England',
#   'name': 'Francis Frith',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Samuel Middiman', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Louisa Augusta Greville',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'J. Widnell', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'George Cooke', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'D. J. Pound', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Charles Heath Wilson',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Peltro', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Peter William Tomkins',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Sayre', 'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'Edward William Cooke',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'W. L. Walton', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Alfred Ashley', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'David Martin', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'J. Radclyffe', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Thomas Sanders', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Harris', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Joseph Coplans', 'nationality': 'British'},
#  {'birthplace': 'Halifax, W. Yorkshire',
#   'name': 'Matthew Arnold Bracy Smith',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Henry Roberts', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Charles T. Scowen', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Mary Georgiana Caroline Cecil Filmer',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Smith', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Raphael Tuck and Sons',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'G. W. Bacon & Co.', 'nationality': 'British'},
#  {'birthplace': '1858, Born in New Cross, Deptford ',
#   'name': 'William Slade Stuart',
#   'nationality': 'British'},
#  {'birthplace': 'Wooler, England',
#   'name': 'George Dalziel',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Walker', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'John Chessell Buckler',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Winstanley', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Lawrence Kilburn', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Typo-Etching Company',
#   'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Matthew Henry Wilson',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'George Beaumont', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Thomas Malton II', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Harwood', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Henry William Bunbury',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Thomas Gibson', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Pars', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Chawner', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Isaac Whood', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Samuel Joseph', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Alexander Browne', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Collins', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Riley', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Edward Radford', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'William Charles Brown',
#   'nationality': 'British'},
#  {'birthplace': 'Halesowen, England',
#   'name': 'Amos Green',
#   'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'Rachel Whiteread',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'J. Harris', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'John Joseph Stockdale',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Frederick Newenham', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Achim Borchardt-Hume',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Dickes', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Charles Reuben Ryley',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Marshall', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Frederick Richard Pickersgill',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Rev. John Williams', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Fanny Corbaux', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Giles Eccardt', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Peter Monamy', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'William John Newton', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Britton', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Norbert Lynton', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'R. Caton Woodville', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Nick Waplington', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Joseph Sympson Jr.', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'A. H. Cade', 'nationality': 'British?'},
#  {'birthplace': None, 'name': 'C. A. Duval & Co.', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Jacob', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Nathaniel Gulliver', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Bell and Daldy', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Cornelius Jabez Hughes',
#   'nationality': 'British'},
#  {'birthplace': 'Paris',
#   'name': 'Gilliana McMullenia Test One',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'John A. Huybers', 'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'Thomas Rowlandson',
#   'nationality': 'British'},
#  {'birthplace': 'Aberdeen, Scotland',
#   'name': 'James McBey',
#   'nationality': 'British'},
#  {'birthplace': 'Bristol, England',
#   'name': 'William James Muller',
#   'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Horne & Thornthwaite',
#   'nationality': 'British'},
#  {'birthplace': 'Wolverhampton, England',
#   'name': 'David Rayson',
#   'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Portman Photographic Studio',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'H. Crickmore', 'nationality': 'British'},
#  {'birthplace': 'Skipton, North Yorkshire, England',
#   'name': 'Leslie T. Thornton',
#   'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'William Turner of Oxford',
#   'nationality': 'British'},
#  {'birthplace': 'Hamburg, Germany',
#   'name': 'Bill Brandt',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Samuel Toulmin', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Edmund Blampied', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Charles Howard Hodges',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Joseph Horner', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Berenice Sydney', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Abraham Le Blond', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Roffe', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Lionel Bicknell Constable',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'W. R. Smith', 'nationality': 'British'},
#  {'birthplace': 'Letchworth, England',
#   'name': 'Richard Smith',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Thomas Goff Lupton', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'H. White', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Philip Audinet', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Francis Crump', 'nationality': 'British'},
#  {'birthplace': 'London, England',
#   'name': 'Edward Lear',
#   'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Ronald Charles Sutherland Leveson Gower',
#   'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Constantine Jennings',
#   'nationality': 'British'},
#  {'birthplace': 'Headingley, Yorkshire, 13 December',
#   'name': 'Adolphe Smith',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'George Margetts', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'George Western', 'nationality': 'British'},
#  {'birthplace': 'Plymouth, England',
#   'name': 'Samuel Prout',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'John E Nicholls', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Thomas Tompion', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Benjamin Waterhouse Hawkins',
#   'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'James William Edmund Doyle',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Jacob Thompson', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'George Edwards Hering',
#   'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Henry William Pickersgill',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Colvin Smith', 'nationality': 'British'},
#  {'birthplace': 'Burslem, England',
#   'name': 'Enoch Wood',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'Robert West', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Thomas Worlidge', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Collins', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Benjamin Phelps Gibbon',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'H. Humphrey', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Ian McKay', 'nationality': 'British'},
#  {'birthplace': 'New Malden, Surrey, England',
#   'name': 'Anthony Caro',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Clerk of Eldin', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Charles Cousen', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Bradshaw & Blacklock',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'George Baxter', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Fullwood', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'J. H. Baker', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Burnet', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Jean Pierre Simon', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'Edward M. Synge', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Le Keux', 'nationality': 'British'},
#  {'birthplace': None, 'name': 'John Simon', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'Richard Austin Artlett',
#   'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'William Charles Wilson',
#   'nationality': 'British'},
#  {'birthplace': None, 'name': 'William Preist', 'nationality': 'British'},
#  {'birthplace': None,
#   'name': 'William Rogers & Co.',
#   'nationality': 'British?'},
#  {'birthplace': None, 'name': 'Joseph Baker', 'nationality': 'British'},
#  ...]
